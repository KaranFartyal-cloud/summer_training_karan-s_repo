# %%
import pandas as pd

# Load the file
df = pd.read_csv('data1.csv')

# View the first 5 rows
df.head()
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)

# %%
df.tail()
# Out:
#                date  number_of_strikes  center_point_geom
# 3401007  2018-12-28                 30  POINT(-90.6 28.7)
# 3401008  2018-12-28                 30  POINT(-89.4 30.9)
# 3401009  2018-12-28                 30  POINT(-89.5 31.4)
# 3401010  2018-12-28                 30  POINT(-88.3 31.6)
# 3401011  2018-12-28                 30  POINT(-88.4 32.1)

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3401007    False
# 3401008    False
# 3401009    False
# 3401010    False
# 3401011    False
# Length: 3401012, dtype: bool

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3401007    False
# 3401008    False
# 3401009    False
# 3401010    False
# 3401011    False
# Length: 3401012, dtype: bool>

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#        number_of_strikes
# count       3.401012e+06
# mean        1.311403e+01
# std         3.212099e+01
# min         1.000000e+00
# 25%         2.000000e+00
# 50%         4.000000e+00
# 75%         1.200000e+01
# max         2.211000e+03

# %%
df["center_point_geom"].head()
# Out:
# 0      POINT(-75 27)
# 1    POINT(-78.4 29)
# 2    POINT(-73.9 27)
# 3    POINT(-73.8 27)
# 4      POINT(-79 28)
# Name: center_point_geom, dtype: str
