# %%
a = 10
a
# Out:
# 10

# %%
print(a + 10)
# Out:
# 20

# %%
# input somme parameters from the user so that

# %%
# github -> summer_training_% repo
# summer_training_project

#

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
c = np.array([1, 2, 3])
d = np.array([2, 4, 5])

# %%
c + d
# Out:
# array([3, 6, 8])

# %%
c - d
# Out:
# array([-1, -2, -2])

# %%
c * d
# Out:
# array([ 2,  8, 15])

# %%
c / d
# Out:
# array([0.5, 0.5, 0.6])

# %%
c // d
# Out:
# array([0, 0, 0])

# %%
c % d
# Out:
# array([1, 2, 3])

# %%
c ** d
# Out:
# array([  1,  16, 243])

# %%
#

# %%
a = np.array([[1,2,3], [2,3,4]])
b = np.array([[2,3,4], [3,4,6]])

# %%
a + b
# Out:
# array([[ 3,  5,  7],
#        [ 5,  7, 10]])

# %%
a * b
# Out:
# array([[ 2,  6, 12],
#        [ 6, 12, 24]])

# %%
a ** b
# Out:
# array([[   1,    8,   81],
#        [   8,   81, 4096]])

# %%
a - b
# Out:
# array([[-1, -1, -1],
#        [-1, -1, -2]])

# %%
a / b
# Out:
# array([[0.5       , 0.66666667, 0.75      ],
#        [0.66666667, 0.75      , 0.66666667]])

# %%
a // b
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
a % b
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
c = np.transpose(b)

# %%
np.dot(a,c)
# Out:
# array([[20, 29],
#        [29, 42]])

# %%
np.shape(a)
# Out:
# (2, 3)

# %%
np.size(a)
# Out:
# 6

# %%
np.ndim(a)
# Out:
# 2
